# %%
# Cell 1: Imports & paths (edit these paths if your layout differs)
import os
from pathlib import Path
import json
import joblib
import numpy as np
import pandas as pd

# Change these if your files are in different places
DATA_PATH = Path("data/flows_features_cicids.csv")   # your main dataset
MODELS_DIR = Path("models")                          # where rf_cicids.pkl & scaler are saved
OUT_DIR = Path("reports/eval_notebook")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# model filename to evaluate (you can change to other model files)
MODEL_FILENAME = "rf_cicids.pkl"   # typical name from your training
MODEL_META_FILENAME = "rf_cicids_meta.json"  # metadata saved in training (features list)
SCALER_CANDS = ["scaler_cicids.pkl", "scaler.pkl", "scaler.joblib"]  # candidate scaler names
